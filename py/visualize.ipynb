# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
traj = np.load("../generated_lam/gen_laminar_a1.8-1.7_omega0.225_n100000_check50_progress10_perturb-15--8.npy")

# %%
epsilon = 0.3

I = np.array([0, 1])
upper = I+np.sqrt(2)*epsilon
lower = I-np.sqrt(2)*epsilon

fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
ax.set_ylim([0, 1])
ax.set_xlim([0, 1])

# ax.fill_between(I, lower, upper, facecolor='r', alpha=0.5)
ax.scatter(traj[0, :], traj[1, :], s=0.001)
